# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: ipykernel in a:\anaconda3\lib\site-packages (from myst-nb~=0.17.1->jupyter-book) (6.9.1)
# ...
#
# ...
